# %%
import random

# List of questions and answers in multiple choice format
qa_list = [
    ("What is the definition of a budget?", ["A plan outlining financial goals", "A list of expenses", "A method to increase income"], 0),
    ("What is an interest rate?", ["The percentage charged on a loan", "The total amount of a loan", "The term of a loan"], 0),
    ("What does ROI stand for in finance?", ["Rate of Interest", "Return on Investment", "Revenue on Income"], 1),
    ("What is a credit score?", ["A measure of creditworthiness", "An interest rate on a loan", "A type of bank account"], 0),
    ("What is the purpose of a savings account?", ["Store money and earn interest", "Increase spending power", "Reduce debts"], 0),
    ("What is a mutual fund?", ["A single investment", "A pool of money from many investors", "A type of savings account"], 1),
    ("What is the difference between a stock and a bond?", ["Ownership vs Loan", "Fixed vs Variable", "Short-term vs Long-term"], 0),
    ("What is compound interest?", ["Interest on initial principal only", "Interest on both initial principal and accumulated interest", "Fixed interest"], 1),
    ("What is diversification in investing?", ["Spreading investments to reduce risk", "Investing in one asset", "Maximizing returns"], 0),
    ("What is a dividend?", ["A profit distribution to shareholders", "A loan payment", "A savings account bonus"], 0),
    ("What is inflation?", ["General rise in prices", "Decrease in investment value", "Stable prices"], 0),
    ("What is a 401(k) plan?", ["A retirement savings plan", "A short-term loan", "A high-interest savings account"], 0),
    ("What is an emergency fund?", ["A savings for unexpected expenses", "A loan for emergencies", "A type of insurance"], 0),
    ("What is a mortgage?", ["A loan to purchase real estate", "An investment in stocks", "A credit card payment"], 0),
    ("What is a credit card?", ["A payment card for borrowing funds", "A savings account card", "A debit card"], 0),
    ("What is net worth?", ["Assets minus liabilities", "Total income", "Total expenses"], 0),
    ("What is an asset?", ["Any resource with economic value", "A financial liability", "A type of loan"], 0),
    ("What is a liability?", ["A financial obligation or debt", "A financial asset", "A savings account"], 0),
    ("What is a balance sheet?", ["A financial statement summarizing assets, liabilities, and equity", "An income statement", "A cash flow statement"], 0),
    ("What is an income statement?", ["A financial statement showing revenues, expenses, and profits", "A balance sheet", "A budget plan"], 0),
    ("What is a cash flow statement?", ["A financial statement showing cash inflow and outflow", "A credit report", "A tax return"], 0),
    ("What is a bond yield?", ["The return on a bond investment", "The bond's interest rate", "The bond's maturity date"], 0),
    ("What is market capitalization?", ["Total value of a company's outstanding shares", "Total company revenue", "Total company expenses"], 0),
    ("What is a stock market index?", ["A measurement of the performance of a group of stocks", "A single stock's price", "Total stock market value"], 0),
    ("What is a bull market?", ["A period of rising stock prices", "A period of declining stock prices", "A period of stable stock prices"], 0),
    ("What is a bear market?", ["A period of declining stock prices", "A period of rising stock prices", "A period of stable stock prices"], 0),
    ("What is a capital gain?", ["Profit from selling an asset at a higher price", "Loss from selling an asset at a lower price", "Income from investments"], 0),
    ("What is a financial advisor?", ["A professional providing financial guidance", "A loan officer", "A bank teller"], 0),
    ("What is a brokerage account?", ["An investment account for buying and selling securities", "A savings account", "A loan account"], 0),
    ("What is an IRA?", ["An Individual Retirement Account", "A short-term loan", "A credit card"], 0),
    ("What is a high-yield savings account?", ["A savings account with higher interest rates", "A low-interest loan", "A checking account"], 0),
    ("What is an ETF?", ["An Exchange-Traded Fund", "A type of bond", "A savings account"], 0),
    ("What is a stockbroker?", ["A professional buying and selling stocks for clients", "A bank manager", "A financial analyst"], 0),
    ("What is a financial planner?", ["A professional helping individuals manage finances", "A credit counselor", "A tax advisor"], 0),
    ("What is the difference between a credit card and a debit card?", ["Borrowed funds vs bank account funds", "Fixed vs variable rates", "Short-term vs long-term"], 0),
    ("What is a money market account?", ["A savings account with higher interest rates", "A brokerage account", "A loan account"], 0),
    ("What is a certificate of deposit (CD)?", ["A savings account with fixed interest and maturity date", "A type of bond", "A checking account"], 0),
    ("What is a financial statement?", ["A document providing an overview of financial condition", "A credit report", "A tax return"], 0),
    ("What is a hedge fund?", ["An investment fund using various strategies", "A savings account", "A loan fund"], 0),
    ("What is a real estate investment trust (REIT)?", ["A company owning income-generating real estate", "A type of mortgage", "A savings account"], 0),
    ("What is a stock option?", ["A right to buy or sell a stock at a specific price", "A savings bond", "A mutual fund"], 0),
    ("What is a bond?", ["A loan made by an investor to a borrower", "A stock", "A savings account"], 0),
    ("What is a money market fund?", ["A mutual fund investing in short-term securities", "A savings account", "A loan fund"], 0),
    ("What is an annuity?", ["A financial product providing regular payments", "A savings account", "A loan"], 0),
    ("What is a stock?", ["Ownership in a company", "A loan", "A savings account"], 0),
    ("What is a mutual fund?", ["A pool of money from many investors", "A single investment", "A loan"], 0),
    ("What is a loan?", ["A sum of money borrowed to be paid back with interest", "A savings account", "A financial statement"], 0),
    ("What is a financial market?", ["A marketplace for trading financial assets", "A savings account", "A loan market"], 0)
]

# List of badges
badges = ["Bronze Badge", "Silver Badge", "Gold Badge", "Platinum Badge"]

def get_badge(correct_answers):
    if correct_answers < 10:
        return badges[0]
    elif correct_answers < 30:
        return badges[1]
    elif correct_answers < 45:
        return badges[2]
    else:
        return badges[3]

def play_game():
    print("Welcome to the Finance Knowledge Game!")
    print("Answer the following questions to earn badges. Type 'exit' to end the game at any point.\n")
    
    random.shuffle(qa_list)
    correct_answers = 0
    
    for i, (question, choices, correct_index) in enumerate(qa_list):
        print(f"Question {i + 1}: {question}")
        for j, choice in enumerate(choices):
            print(f"{j + 1}. {choice}")
        user_answer = input("Your answer (1/2/3) or type 'exit' to end the game: ").strip()
        
        if user_answer.lower() == 'exit':
            print("Game exited by the user.")
            break
        
        if user_answer.isdigit() and int(user_answer) - 1 == correct_index:
            print("Correct!")
            correct_answers += 1
        else:
            print(f"Wrong! The correct answer is: {choices[correct_index]}")
        print()
    
    badge = get_badge(correct_answers)
    print(f"You answered {correct_answers} questions correctly.")
    print(f"Congratulations! You earned the {badge}!")

# Start the game
play_game()
# Out:
# Welcome to the Finance Knowledge Game!
# Answer the following questions to earn badges. Type 'exit' to end the game at any point.
#
# Question 1: What is a bond?
# 1. A loan made by an investor to a borrower
# 2. A stock
# 3. A savings account
